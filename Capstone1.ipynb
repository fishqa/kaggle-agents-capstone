# %%
# This Python 3 environment comes with many helpful analytics libraries installed
# It is defined by the kaggle/python Docker image: https://github.com/kaggle/docker-python
# For example, here's several helpful packages to load

import numpy as np # linear algebra
import pandas as pd # data processing, CSV file I/O (e.g. pd.read_csv)

# Input data files are available in the read-only "../input/" directory
# For example, running this (by clicking run or pressing Shift+Enter) will list all files under the input directory

import os
for dirname, _, filenames in os.walk('/kaggle/input'):
    for filename in filenames:
        print(os.path.join(dirname, filename))

# You can write up to 20GB to the current directory (/kaggle/working/) that gets preserved as output when you create a version using "Save & Run All" 
# You can also write temporary files to /kaggle/temp/, but they won't be saved outside of the current session

# %%
import os
from kaggle_secrets import UserSecretsClient

try:
    GOOGLE_API_KEY = UserSecretsClient().get_secret("GOOGLE_API_KEY")
    os.environ["GOOGLE_API_KEY"] = GOOGLE_API_KEY
    print("✅ Gemini API key setup complete.")
except Exception as e:
    print(
        f"🔑 Authentication Error: Please make sure you have added 'GOOGLE_API_KEY' to your Kaggle secrets. Details: {e}"
    )
# Out:
# ✅ Gemini API key setup complete.

# %%
from google.adk.agents import Agent, LlmAgent, SequentialAgent, ParallelAgent, LoopAgent
from google.adk.models.google_llm import Gemini
from google.adk.runners import InMemoryRunner, Runner
from google.adk.tools import AgentTool, FunctionTool, google_search
from google.genai import types

from google.adk.sessions import InMemorySessionService

print("✅ ADK components imported successfully.")
# Out:
# ✅ ADK components imported successfully.

# %%
retry_config=types.HttpRetryOptions(
    attempts=5,  # Maximum retry attempts
    exp_base=7,  # Delay multiplier
    initial_delay=1, # Initial delay before first retry (in seconds)
    http_status_codes=[429, 500, 503, 504] # Retry on these HTTP errors
)

# %%
# Define helper functions that will be reused throughout the notebook
async def run_session(
    runner_instance: Runner,
    user_queries: list[str] | str = None,
    session_name: str = "default",
):
    print(f"\n ### Session: {session_name}")

    # Get app name from the Runner
    app_name = runner_instance.app_name

    # Attempt to create a new session or retrieve an existing one
    try:
        session = await session_service.create_session(
            app_name=app_name, user_id=USER_ID, session_id=session_name
        )
    except:
        session = await session_service.get_session(
            app_name=app_name, user_id=USER_ID, session_id=session_name
        )

    # Process queries if provided
    if user_queries:
        # Convert single query to list for uniform processing
        if type(user_queries) == str:
            user_queries = [user_queries]

        # Process each query in the list sequentially
        for query in user_queries:
            print(f"\nUser > {query}")

            # Convert the query string to the ADK Content format
            query = types.Content(role="user", parts=[types.Part(text=query)])

            # Stream the agent's response asynchronously
            async for event in runner_instance.run_async(
                user_id=USER_ID, session_id=session.id, new_message=query
            ):
                # Check if the event contains valid content
                if event.content and event.content.parts:
                    # Filter out empty or "None" responses before printing
                    if (
                        event.content.parts[0].text != "None"
                        and event.content.parts[0].text
                    ):
                        print(event.content.parts[0].text)
    else:
        print("No queries!")


print("✅ Helper functions defined.")
# Out:
# ✅ Helper functions defined.

# %%
# Research Agent: Its job is to use the google_search tool and present findings.
research_agent = Agent(
    name="OpenDatasetSeeker",
    model=Gemini(
        model="gemini-2.5-flash-lite",
        retry_options=retry_config
    ),
    instruction="""You are an open data research agent. Your job is to use the
    google_search tool to find several open data sources of relevant information on the given topic and present the 
    findings like a list of the datasources along with their description and explaining what exact data can be taken from there""",
    tools=[google_search],
    output_key="dataset_findings",  # The result of this agent will be stored in the session state with this key.
)

print("✅ OpenDatasetSeeker created.")
# Out:
# ✅ OpenDatasetSeeker created.

# %%
# Summarizer Agent: Its job is to summarize the text it receives.
single_dataset_agent = Agent(
    name="SingleDatasetAgent",
    model=Gemini(
        model="gemini-2.5-flash-lite",
        retry_options=retry_config
    ),
    # The instruction is modified to request a bulleted list for a clear output format.
    instruction="""Your goal is to compose the list of parameters which can be taken from each of the provided datasources 
    in order to get comprehencive data-driven view on the topic. Create a summary of what data is available and from what source""",
    output_key="final_summary",
)

print("✅ SingleDatasetAgent created.")
# Out:
# ✅ SingleDatasetAgent created.

# %%
# Root Coordinator: Orchestrates the workflow by calling the sub-agents as tools.
root_agent = SequentialAgent(
    name="ResearchCoordinator",
    sub_agents=[research_agent, single_dataset_agent]
)

print("✅ root_agent created.")
# Out:
# ✅ root_agent created.

# %%
APP_NAME = "default"  # Application
USER_ID = "default"  # User
SESSION = "default"
session_service = InMemorySessionService()
runner = Runner(agent=root_agent, app_name=APP_NAME, session_service=session_service)
print("✅ Runner created.")
# Out:
# ✅ Runner created.

# %%
response = await run_session(
    runner,
    [
    "What countrues in Europe consume the most electricity?",
        "Which country out of these has the larget GDP?"]
)
# Out:
#  ### Session: default
#
# User > What countrues in Europe consume the most electricity?
# When looking at electricity consumption in Europe, it's important to consider both total consumption and consumption per capita.
#
# **Countries with the Highest Total Electricity Consumption (2023):**
# *   **Germany:** 515 TWh
# *   **France:** 464 TWh
# *   **Italy:** 315 TWh
# *   **United Kingdom:** 319 billion kWh
# *   **Spain:** 256 TWh
# *   **Poland:** 145 billion kWh
# *   **Sweden:** 129 billion kWh
# *   **Norway:** 116 billion kWh
# *   **Netherlands:** 107 billion kWh
#
# **Countries with the Highest Electricity Consumption Per Capita (2022/2023):**
# *   **Iceland:** 52,920 kWh/year
# *   **Norway:** 23,374 kWh/year
# *   **Finland:** 14,747 kWh/year
# *   **Sweden:** 12,122 kWh/year
# *   **Luxembourg:** 11,168 kWh/year
#
# **Key Data Sources for European Electricity Consumption:**
#
# *   **Ember:** This organization provides detailed annual reports on the European electricity sector, including data on electricity generation, demand, and emissions. Their data is available for EU-27 countries and offers insights into trends and progress in transitioning to clean electricity. They offer yearly and monthly data for many countries.
# *   **International Energy Agency (IEA):** The IEA offers a comprehensive source of global energy data, including statistics on energy supply and demand for countries across Europe. Their data includes energy balances, prices, and efficiency measures, with time series data stretching back to 1971.
# *   **Eurostat:** As the statistical office of the European Union, Eurostat collects and publishes data on energy consumption, including household electricity consumption and energy use by sector across EU member states.
# *   **World Bank Open Data:** This platform provides access to various development indicators, including electricity consumption per capita for European countries.
# *   **Wikipedia:** While not a primary data source, Wikipedia's lists of countries by electricity consumption and per capita consumption often compile data from reputable sources like the IEA and World Bank, providing a good overview and linking to original data.
# *   **Data Commons:** This initiative from Google provides tools to explore and visualize data, including energy consumption data for various countries, including those in Europe.
# ## Summary of Available Data on European Electricity Consumption
#
# The provided context offers insights into European electricity consumption, differentiating between **total consumption** and **consumption per capita**.
#
# **Total Electricity Consumption:**
#
# *   **Data Points:** The data lists specific countries and their total electricity consumption in Terawatt-hours (TWh) or billion kilowatt-hours (kWh).
# *   **Timeframe:** The data for total consumption is primarily for the year 2023, with some older data also mentioned.
# *   **Countries Covered:** Germany, France, Italy, Spain, United Kingdom, Russian Federation, Poland, Sweden, Norway, and Netherlands are explicitly listed.
# *   **Key Sources Mentioned:** International Energy Agency (IEA), Data Commons, Ember, IndexMundi, and implicitly through country listings which likely draw from these or similar sources.
#
# **Electricity Consumption Per Capita:**
#
# *   **Data Points:** The data lists specific countries and their electricity consumption per person per year in kWh or MWh.
# *   **Timeframe:** The data for per capita consumption is for 2022/2023.
# *   **Countries Covered:** Iceland, Norway, Finland, Sweden, and Luxembourg are explicitly listed.
# *   **Key Sources Mentioned:** International Energy Agency (IEA), Data Commons, World Bank Open Data, and implicitly through country listings.
#
# **Detailed Breakdown by Source and Parameters:**
#
# Here's a more detailed look at the data available from each mentioned source and the parameters that can be extracted:
#
# ---
#
# **1. Ember**
#
# *   **Summary:** Ember is a key source for detailed annual and monthly reports on the European electricity sector, focusing on generation, demand, and emissions. Their data is particularly strong for EU-27 countries and covers trends in clean electricity transitions.
# *   **Available Parameters:**
#     *   `electricity_consumption_total` (yearly, monthly)
#     *   `electricity_demand` (yearly, monthly)
#     *   `electricity_generation` (yearly, monthly)
#     *   `electricity_emissions` (yearly, monthly)
#     *   `country`
#     *   `region` (e.g., EU-27)
#     *   `year`
#     *   `month`
#     *   `data_type` (e.g., actual, forecast)
#     *   `source_of_electricity` (e.g., renewable, fossil fuel, nuclear)
#
# ---
#
# **2. International Energy Agency (IEA)**
#
# *   **Summary:** The IEA provides a comprehensive global energy database, including extensive statistics on energy supply and demand for European countries. Their data is long-term and detailed, covering energy balances, prices, and efficiency.
# *   **Available Parameters:**
#     *   `electricity_consumption_total` (yearly)
#     *   `electricity_consumption_per_capita` (yearly)
#     *   `energy_supply_and_demand` (various forms of energy)
#     *   `energy_balances`
#     *   `energy_prices`
#     *   `energy_efficiency_measures`
#     *   `country`
#     *   `region`
#     *   `year` (time series data available from 1971)
#     *   `energy_sector`
#
# ---
#
# **3. Eurostat**
#
# *   **Summary:** As the statistical office of the European Union, Eurostat collects and publishes detailed data on energy consumption specifically for EU member states, including breakdowns by sector.
# *   **Available Parameters:**
#     *   `electricity_consumption_total` (yearly)
#     *   `electricity_consumption_per_capita` (yearly)
#     *   `household_electricity_consumption` (yearly)
#     *   `energy_use_by_sector` (e.g., industry, residential, transport)
#     *   `country` (EU member states)
#     *   `year`
#     *   `sector`
#
# ---
#
# **4. World Bank Open Data**
#
# *   **Summary:** This platform offers a variety of development indicators, including electricity consumption per capita for European countries.
# *   **Available Parameters:**
#     *   `electricity_consumption_per_capita` (yearly)
#     *   `country`
#     *   `year`
#
# ---
#
# **5. Data Commons**
#
# *   **Summary:** Data Commons provides tools for data exploration and visualization, including energy consumption data for countries worldwide.
# *   **Available Parameters:**
#     *   `electricity_consumption_total` (various years)
#     *   `electricity_consumption_per_capita` (various years)
#     *   `country`
#     *   `year`
#     *   `ranking` (for electricity consumption per capita)
#
# ---
#
# **6. IndexMundi**
#
# *   **Summary:** IndexMundi offers electricity consumption data by country, often presented in billion kWh.
# *   **Available Parameters:**
#     *   `electricity_consumption_total` (in billion kWh)
#     *   `country`
#     *   `year` (specific year data may vary)
#
# ---
#
# **7. Wikipedia**
#
# *   **Summary:** While not a primary data source, Wikipedia compilations are useful for getting an overview and discovering links to original sources.
# *   **Available Parameters:**
#     *   `electricity_consumption_total` (compiled from various sources)
#     *   `electricity_consumption_per_capita` (compiled from various sources)
#     *   `country`
#     *   `year` (often lists data for recent years)
#     *   `source_links` (crucial for verifying and accessing primary data)
#
# ---
#
# **8. Specific Country Data (Implicit)**
#
# *   **Summary:** The provided text lists specific consumption figures for countries like Germany, France, Italy, etc., for 2023. This implies that national statistical agencies or energy ministries of these countries are also primary data sources.
# *   **Available Parameters (Likely):**
#     *   `electricity_consumption_total`
#     *   `electricity_consumption_per_capita`
#     *   `country`
#     *   `year`
#     *   `sectoral_consumption`
#     *   `generation_mix`
#
# To obtain a truly comprehensive data-driven view, it would be beneficial to consult these primary sources directly for the most up-to-date and granular data, using the cited sources as excellent starting points and cross-referencing tools.
#
# User > Which country out of these has the larget GDP?
# Based on the provided data for 2023, **Germany** has the largest GDP among the listed European countries.
#
# Here's a breakdown of the nominal GDP for the countries in question:
#
# *   **Germany:** $4.526 trillion USD
# *   **United Kingdom:** $3.381 trillion USD
# *   **France:** $3.052 trillion USD
# *   **Italy:** $2.301 trillion USD
# *   **Spain:** $1.620 trillion USD
# *   **Netherlands:** $1.154 trillion USD
# *   **Poland:** $0.809 trillion USD
# *   **Sweden:** $0.585 trillion USD
# *   **Norway:** $0.485 trillion USD
#
# Therefore, Germany has the largest GDP among these countries.
# ## Summary of Available Data on European GDP
#
# The provided context offers a clear comparison of Nominal GDP for several European countries in 2023.
#
# **GDP Data:**
#
# *   **Data Points:** The data lists specific countries and their nominal GDP in trillions of US Dollars (USD).
# *   **Timeframe:** The data is for the year 2023.
# *   **Countries Covered:** Germany, United Kingdom, France, Italy, Spain, Netherlands, Poland, Sweden, and Norway are explicitly listed.
# *   **Key Sources Mentioned:** While not explicitly stated for this particular snippet, GDP data for countries typically comes from sources like the **International Monetary Fund (IMF)**, the **World Bank**, and national statistical agencies. The context states "Based on the provided data," implying a specific dataset was used.
#
# **Available Parameters:**
#
# *   `country`
# *   `nominal_gdp` (in trillions of USD)
# *   `year`
#
# To get a more comprehensive view, one could expand this by looking into:
#
# *   **GDP per capita:** To understand economic output relative to population.
# *   **Purchasing Power Parity (PPP) GDP:** To account for differences in the cost of living.
# *   **Historical GDP data:** To observe trends over time.
# *   **GDP by sector:** To understand the economic structure of each country.
#
# This information would likely be available from the **IMF**, **World Bank**, **Eurostat** (for EU countries), and national statistical offices.
